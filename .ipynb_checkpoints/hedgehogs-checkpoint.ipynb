# %%
#hide
from utils import *
from fastai.vision.widgets import *

# %%
import os

# %%
key = '60cba06b608f4105b5db1483a4164582'

# %%
results = search_images_bing(key, 'hedgehog')
ims = results.attrgot('content_url')
len(ims)
# Out:
# 150

# %%
ims[3]
# Out:
# 'https://media.npr.org/assets/img/2016/01/25/7856738032_74e9cc0807_o_wide-d9e64ff1bfa51089561a9ff1dc276dc10ad86796.jpg?s=1400'

# %%
#hide
# ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/hedgie.jpg'
download_url(ims[4], dest)

# %%
im = Image.open(dest)
im.to_thumb(512,512)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7F252A90E2B0>

# %%
hog_types = 'hedge','hog','hedgehog'
path = Path('hedgehogs')

# %%
if not path.exists():
    path.mkdir()
    for o in hog_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o}')
        download_images(dest, urls=results.attrgot('content_url'))

# %%
fns = get_image_files(path)
len(fns)
# Out:
# 443

# %%
failed = verify_images(fns)
len(failed)
# Out:
# 0

# %%
failed.map(Path.unlink);

# %%
hogs = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = hogs.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
hogs = hogs.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = hogs.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
hogs = hogs.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = hogs.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
hogs = hogs.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = hogs.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
hogs = hogs.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = hogs.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
hogs = hogs.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = hogs.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.522003</td>
#       <td>0.323906</td>
#       <td>0.090909</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.213862</td>
#       <td>0.150877</td>
#       <td>0.045455</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.166122</td>
#       <td>0.049739</td>
#       <td>0.034091</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.177957</td>
#       <td>0.016175</td>
#       <td>0.011364</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.158640</td>
#       <td>0.017613</td>
#       <td>0.000000</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('hedge', 'hedgehog', 'hog'), value='hedge'), Dropdown(options=('Train', 'Vali…

# %%
def get_xiaomi(N=1):
    picdir = "/home/brandon/Pictures/Xiaomi/select"
    xiaomipics = os.listdir(picdir)
    return os.path.join(picdir, xiaomipics[N])

# %%
N = 40
xiaomi_pic = get_xiaomi(N)
im = Image.open(xiaomi_pic)
print(learn.predict(xiaomi_pic))
im.to_thumb(512,512)
# Out:
# ('hedgehog', tensor(1), tensor([2.3587e-06, 1.0000e+00, 3.5530e-08]))
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F252A9081F0>

# %%
flowers = "/home/brandon/Desktop/flowers.jpg"
im = Image.open(flowers)
print(learn.predict(flowers))
im.to_thumb(512,512)
# Out:
# ('hedge', tensor(0), tensor([9.9811e-01, 1.7203e-03, 1.7025e-04]))
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F24C46EDF40>

# %%
piglet = "/home/brandon/Desktop/piglet.jpg"
im = Image.open(piglet)
print(learn.predict(piglet))
im.to_thumb(512,512)
# Out:
# ('hog', tensor(2), tensor([0.0156, 0.0246, 0.9598]))
# <PIL.Image.Image image mode=RGB size=512x266 at 0x7F252D807970>

# %%
#hide
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)
